# %% [markdown]
# <a href="https://colab.research.google.com/github/ananthavarshinireddy123-ai/Varshani-Reddy/blob/main/reportcard.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Student Report Card Program

# List to store student names
student_names = []

# Get student details
name = input("Enter Student Name: ")
age = int(input("Enter Age: "))
num_subjects = int(input("Enter Number of Subjects: "))

# Store name in list
student_names.append(name)

# Store student info in tuple
student_info = (name, age)

# Set to store subjects
subjects = set()

# Dictionary to store subject-wise marks
marks_dict = {}

# Input subjects and marks
for i in range(num_subjects):
    subject = input(f"Enter Subject {i+1} Name: ")
    marks = float(input(f"Enter Marks in {subject}: "))

    subjects.add(subject)
    marks_dict[subject] = marks

# Calculate total and average
total_marks = sum(marks_dict.values())
average_marks = total_marks / num_subjects

# Print Report Card
print("\n" + "=" * 30)
print("       STUDENT REPORT CARD")
print("=" * 30)

print("Name :", student_info[0])
print("Age  :", student_info[1])

print("\nSubjects:")
for subject in subjects:
    print("-", subject)

print("\nMarks:")
for subject, marks in marks_dict.items():
    print(f"{subject} : {marks}")

print("\nTotal Marks   :", total_marks)
print("Average Marks :", round(average_marks, 2))

print("=" * 30)

# Display stored data structures
print("\nStored Data Structures:")
print("List (Student Names):", student_names)
print("Tuple (Student Info):", student_info)
print("Set (Subjects):", subjects)
print("Dictionary (Marks):", marks_dict)
# Out:
# Enter Student Name: aishu
# Enter Age: 14
# Enter Number of Subjects: 6
# Enter Subject 1 Name: maths
# Enter Marks in maths: 100
# Enter Subject 2 Name: science
# Enter Marks in science: 99
# Enter Subject 3 Name: social
# Enter Marks in social: 98
# Enter Subject 4 Name: hindi
# Enter Marks in hindi: 95
# Enter Subject 5 Name: telugu
# Enter Marks in telugu: 96
# Enter Subject 6 Name: english
# Enter Marks in english: 94
#
# ...
#        STUDENT REPORT CARD
# ...
# Name : aishu
# Age  : 14
#
# Subjects:
# - english
# - hindi
# - social
# - science
# - maths
# - telugu
#
# Marks:
# maths : 100.0
# science : 99.0
# social : 98.0
# hindi : 95.0
# telugu : 96.0
# english : 94.0
#
# Total Marks   : 582.0
# Average Marks : 97.0
# ...
#
# Stored Data Structures:
# List (Student Names): ['aishu']
# Tuple (Student Info): ('aishu', 14)
# Set (Subjects): {'english', 'hindi', 'social', 'science', 'maths', 'telugu'}
# ...
