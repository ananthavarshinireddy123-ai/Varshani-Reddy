# %% [markdown]
# <a href="https://colab.research.google.com/github/ananthavarshinireddy123-ai/Varshini-Reddy/blob/main/FeatureEng.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Sample dataset
data = {
    "Name": ["chikki", "teju", "meghna"],
    "Age": [25, 30, 35],
    "Gender": ["Female", "Male", "Male"],
    "Salary": [50000, 60000, 70000],
    "Joining_Date": ["2022-01-01", "2021-06-15", "2020-03-20"]
}

df = pd.DataFrame(data)

# Display dataset
df
# Out:
#      Name  Age  Gender  Salary Joining_Date
# 0  chikki   25  Female   50000   2022-01-01
# 1    teju   30    Male   60000   2021-06-15
# 2  meghna   35    Male   70000   2020-03-20

# %%
# to check datatypes
df.dtypes
# Out:
# Name            object
# Age              int64
# Gender          object
# Salary           int64
# Joining_Date    object
# dtype: object

# %%
# Binning
import pandas as pd
import numpy as np
data={
    'Age':[18,25,30,45,60],
    'Salary':[20000,30000,50000,80000,15000]
}
df=pd.DataFrame(data)
df
# Out:
#    Age  Salary
# 0   18   20000
# 1   25   30000
# 2   30   50000
# 3   45   80000
# 4   60   15000

# %%
# scaling and Standardization

from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
df_scaled=df.copy()
df_scaled[['Age','Salary']]=scaler.fit_transform(df[['Age','Salary']])
df_scaled
# Out:
#         Age    Salary
# 0 -1.167023 -0.800044
# 1 -0.702866 -0.378968
# 2 -0.371325  0.463184
# 3  0.623296  1.726411
# 4  1.617918 -1.010582

# %%
# Feature scaling and Normalization (min and max)
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

df_normalized = df.copy()
df_normalized[["Age", "Salary"]] = scaler.fit_transform(df[["Age", "Salary"]])

df_normalized
# Out:
#         Age    Salary
# 0  0.000000  0.076923
# 1  0.166667  0.230769
# 2  0.285714  0.538462
# 3  0.642857  1.000000
# 4  1.000000  0.000000

# %%
# Apply log transformation
df_log = df.copy()
df_log["Salary_Log"] = np.log(df_log["Salary"])

df_log
# Out:
#    Age  Salary  Salary_Log
# 0   18   20000    9.903488
# 1   25   30000   10.308953
# 2   30   50000   10.819778
# 3   45   80000   11.289782
# 4   60   15000    9.615805

# %%
# Create bins for Age
bins = [0, 20, 40, 100]
labels = ["Young", "Adult", "Senior"]

df["Age_Group"] = pd.cut(df["Age"], bins=bins, labels=labels)

df
# Out:
#    Age  Salary Age_Group
# 0   18   20000     Young
# 1   25   30000     Adult
# 2   30   50000     Adult
# 3   45   80000    Senior
# 4   60   15000    Senior

# %% [markdown]
# Handling categorical data-represents labelled data
# encoding techniques:
# 1.label enocoding
# 2.one-hot encoding
# 3.ordinal encoding
# 4.frequency encoding
# 5.target encoding

# %%
import pandas as pd
data = {
    "Name": ["A", "B", "C", "D", "E","F"],
    "Gender": ["Aale", "Female", "Female", "Male", "Zale","Other"],
    "City": ["Mumbai", "Delhi", "Mumbai", "Pune", "Delhi","Delhi"],
    "Performance": ["Low", "Medium", "High", "Medium", "Low","High"]
}

df = pd.DataFrame(data)
df
# Out:
#   Name  Gender    City Performance
# 0    A    Aale  Mumbai         Low
# 1    B  Female   Delhi      Medium
# 2    C  Female  Mumbai        High
# 3    D    Male    Pune      Medium
# 4    E    Zale   Delhi         Low
# 5    F   Other   Delhi        High

# %%
# label encoding
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

df["Gender_Label"] = le.fit_transform(df["Gender"])
df["City_Label"] = le.fit_transform(df["City"])
df
# Out:
#   Name  Gender    City Performance  Gender_Label  City_Label
# 0    A    Aale  Mumbai         Low             0           1
# 1    B  Female   Delhi      Medium             1           0
# 2    C  Female  Mumbai        High             1           1
# 3    D    Male    Pune      Medium             2           2
# 4    E    Zale   Delhi         Low             4           0
# 5    F   Other   Delhi        High             3           0

# %%
# ordinal encoding -Define order
order = {"Low": 3, "Medium": 2, "High": 1}

df["Performance_Ordinal"] = df["Performance"].map(order)
df
# Out:
#   Name  Gender    City Performance  Gender_Label  City_Label  \
# 0    A    Aale  Mumbai         Low             0           1
# 1    B  Female   Delhi      Medium             1           0
# 2    C  Female  Mumbai        High             1           1
# 3    D    Male    Pune      Medium             2           2
# 4    E    Zale   Delhi         Low             4           0
# 5    F   Other   Delhi        High             3           0
#
#    Performance_Ordinal
# 0                    3
# 1                    2
# 2                    1
# 3                    2
# 4                    3
# 5                    1

# %%
# frequency encoding
freq = df["City"].value_counts()

df["City_Freq"] = df["City"].map(freq)
df
# Out:
#   Name  Gender    City Performance  Gender_Label  City_Label  \
# 0    A    Aale  Mumbai         Low             0           1
# 1    B  Female   Delhi      Medium             1           0
# 2    C  Female  Mumbai        High             1           1
# 3    D    Male    Pune      Medium             2           2
# 4    E    Zale   Delhi         Low             4           0
# 5    F   Other   Delhi        High             3           0
#
#    Performance_Ordinal  City_Freq
# 0                    3          2
# 1                    2          3
# 2                    1          2
# 3                    2          1
# 4                    3          3
# 5                    1          3

# %%
# target encoding
# Create a dummy target variable
df["Target"] = [0, 1, 1, 0, 1,2]

# Calculate mean target per category
target_mean = df.groupby("City")["Target"].mean()

df["City_Target_Encoded"] = df["City"].map(target_mean)
df
# Out:
#   Name  Gender    City Performance  Gender_Label  City_Label  \
# 0    A    Aale  Mumbai         Low             0           1
# 1    B  Female   Delhi      Medium             1           0
# 2    C  Female  Mumbai        High             1           1
# 3    D    Male    Pune      Medium             2           2
# 4    E    Zale   Delhi         Low             4           0
# 5    F   Other   Delhi        High             3           0
#
#    Performance_Ordinal  City_Freq  Target  City_Target_Encoded
# 0                    3          2       0             0.500000
# 1                    2          3       1             1.333333
# 2                    1          2       1             0.500000
# 3                    2          1       0             0.000000
# 4                    3          3       1             1.333333
# 5                    1          3       2             1.333333

# %% [markdown]
# Handling Date-Time

# %%
import pandas as pd

data = {
    "Name": ["A", "B", "C"],
    "Joining_Date": ["2022-01-15", "2021-06-20", "2020-12-05"]
}

df = pd.DataFrame(data)

# Convert to datetime
df["Joining_Date"] = pd.to_datetime(df["Joining_Date"])

df
# Out:
#   Name Joining_Date
# 0    A   2022-01-15
# 1    B   2021-06-20
# 2    C   2020-12-05

# %%
# to extract dates
df["Year"] = df["Joining_Date"].dt.year
df["Month"] = df["Joining_Date"].dt.month
df["Day"] = df["Joining_Date"].dt.day
df["Weekday"] = df["Joining_Date"].dt.day_name()

df
# Out:
#   Name Joining_Date  Year  Month  Day   Weekday
# 0    A   2022-01-15  2022      1   15  Saturday
# 1    B   2021-06-20  2021      6   20    Sunday
# 2    C   2020-12-05  2020     12    5  Saturday

# %%
# Create sample datetime with time
df["Full_DateTime"] = pd.to_datetime([
    "2022-01-15 10:30:00",
    "2021-06-20 14:45:00",
    "2020-12-05 08:15:00"
])

df["Hour"] = df["Full_DateTime"].dt.hour
df["Minute"] = df["Full_DateTime"].dt.minute

df
# Out:
#   Name Joining_Date  Year  Month  Day   Weekday       Full_DateTime  Hour  \
# 0    A   2022-01-15  2022      1   15  Saturday 2022-01-15 10:30:00    10
# 1    B   2021-06-20  2021      6   20    Sunday 2021-06-20 14:45:00    14
# 2    C   2020-12-05  2020     12    5  Saturday 2020-12-05 08:15:00     8
#
#    Minute
# 0      30
# 1      45
# 2      15

# %% [markdown]
# Cyclical encoding

# %%
import numpy as np

# Apply on Month
df["Month_sin"] = np.sin(2 * np.pi * df["Month"] / 12)
df["Month_cos"] = np.cos(2 * np.pi * df["Month"] / 12)

df
# Out:
#   Name Joining_Date  Year  Month  Day   Weekday       Full_DateTime  Hour  \
# 0    A   2022-01-15  2022      1   15  Saturday 2022-01-15 10:30:00    10
# 1    B   2021-06-20  2021      6   20    Sunday 2021-06-20 14:45:00    14
# 2    C   2020-12-05  2020     12    5  Saturday 2020-12-05 08:15:00     8
#
#    Minute     Month_sin  Month_cos
# 0      30  5.000000e-01   0.866025
# 1      45  1.224647e-16  -1.000000
# 2      15 -2.449294e-16   1.000000

# %%
import matplotlib.pyplot as plt

plt.figure()

plt.plot(df["Month"], df["Month_sin"], marker='o', label="sin")
plt.plot(df["Month"], df["Month_cos"], marker='o', label="cos")

plt.xlabel("Month")
plt.ylabel("Value")
plt.title("Cyclical Encoding of Month")
plt.legend()
plt.grid()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Month'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_2108/1208856679.py in <cell line: 0>()
#       3 plt.figure()
#       4
# ----> 5 plt.plot(df["Month"], df["Month_sin"], marker='o', label="sin")
#       6 plt.plot(df["Month"], df["Month_cos"], marker='o', label="cos")
#       7
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4100             if self.columns.nlevels > 1:
#    4101                 return self._getitem_multilevel(key)
# -> 4102             indexer = self.columns.get_loc(key)
#    4103             if is_integer(indexer):
#    4104                 indexer = [indexer]
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3810             ):
#    3811                 raise InvalidIndexError(key)
# -> 3812             raise KeyError(key) from err
#    3813         except TypeError:
#    3814             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'Month'

# %% [markdown]
# Feature creation-creating new features from existing data to improve model performance

# %%
import pandas as pd

data = {
    "Name": ["A", "B", "C"],
    "Price": [100, 200, 150],
    "Quantity": [2, 3, 5],
    "First_Name": ["John", "Jane", "Sam"],
    "Last_Name": ["Doe", "Smith", "Brown"],
    "Email": ["john@gmail.com", "jane@yahoo.com", "sam@outlook.com"]
}

df = pd.DataFrame(data)
df
# Out:
#   Name  Price  Quantity First_Name Last_Name            Email
# 0    A    100         2       John       Doe   john@gmail.com
# 1    B    200         3       Jane     Smith   jane@yahoo.com
# 2    C    150         5        Sam     Brown  sam@outlook.com

# %%
# Create Total Price
df["Total_Price"] = df["Price"] * df["Quantity"]

df
# Out:
#   Name  Price  Quantity First_Name Last_Name            Email  Total_Price
# 0    A    100         2       John       Doe   john@gmail.com          200
# 1    B    200         3       Jane     Smith   jane@yahoo.com          600
# 2    C    150         5        Sam     Brown  sam@outlook.com          750

# %%
# Combing feature
# Full Name
df["Full_Name"] = df["First_Name"] + " " + df["Last_Name"]

df
# Out:
#   Name  Price  Quantity First_Name Last_Name            Email  Total_Price  \
# 0    A    100         2       John       Doe   john@gmail.com          200
# 1    B    200         3       Jane     Smith   jane@yahoo.com          600
# 2    C    150         5        Sam     Brown  sam@outlook.com          750
#
#     Full_Name
# 0    John Doe
# 1  Jane Smith
# 2   Sam Brown

# %%
# Extracting info
#  Extract email domain
df["Email_Domain"] = df["Email"].apply(lambda x: x.split("@")[1])

df
# Out:
#   Name  Price  Quantity First_Name Last_Name            Email  Total_Price  \
# 0    A    100         2       John       Doe   john@gmail.com          200
# 1    B    200         3       Jane     Smith   jane@yahoo.com          600
# 2    C    150         5        Sam     Brown  sam@outlook.com          750
#
#     Full_Name Email_Domain
# 0    John Doe    gmail.com
# 1  Jane Smith    yahoo.com
# 2   Sam Brown  outlook.com

# %%
# Domain based feature
# Add sample data
df["Weight"] = [60, 70, 80]   # kg
df["Height"] = [1.6, 1.7, 1.8]  # meters

# BMI Formula
df["BMI"] = df["Weight"] / (df["Height"] ** 2)

df
# Out:
#   Name  Price  Quantity First_Name Last_Name            Email  Weight  Height  \
# 0    A    100         2       John       Doe   john@gmail.com      60     1.6
# 1    B    200         3       Jane     Smith   jane@yahoo.com      70     1.7
# 2    C    150         5        Sam     Brown  sam@outlook.com      80     1.8
#
#          BMI
# 0  23.437500
# 1  24.221453
# 2  24.691358

# %% [markdown]
# Handling missing data
# Nan
# None
# Blank cell

# %%
# Add sample data
df["Weight"] = [60, 70, 80]   # kg
df["Height"] = [1.6, 1.7, 1.8]  # meters

# BMI Formula
df["BMI"] = df["Weight"] / (df["Height"] ** 2)

df
# Out:
#   Name  Price  Quantity First_Name Last_Name            Email  Total_Price  \
# 0    A    100         2       John       Doe   john@gmail.com          200
# 1    B    200         3       Jane     Smith   jane@yahoo.com          600
# 2    C    150         5        Sam     Brown  sam@outlook.com          750
#
#     Full_Name Email_Domain  Weight  Height        BMI
# 0    John Doe    gmail.com      60     1.6  23.437500
# 1  Jane Smith    yahoo.com      70     1.7  24.221453
# 2   Sam Brown  outlook.com      80     1.8  24.691358

# %%
import pandas as pd
import numpy as np

data = {
    "Age": [25, np.nan, 30, 35, np.nan],
    "Salary": [50000, 60000, np.nan, 80000, 90000],
    "City": ["Mumbai", "Delhi", None, "Pune", "Delhi"]
}

df = pd.DataFrame(data)
df
# Out:
#     Age   Salary    City
# 0  25.0  50000.0  Mumbai
# 1   NaN  60000.0   Delhi
# 2  30.0      NaN    None
# 3  35.0  80000.0    Pune
# 4   NaN  90000.0   Delhi

# %%
df.isnull().sum()
# Out:
# Age       2
# Salary    1
# City      1
# dtype: int64

# %%
df2 = df.copy()
df2["Age"].fillna(df2["Age"].mean(), inplace=True)

df2
# Out:
# /tmp/ipykernel_2458/1096490385.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df2["Age"].fillna(df2["Age"].mean(), inplace=True)
#     Age   Salary    City
# 0  25.0  50000.0  Mumbai
# 1  30.0  60000.0   Delhi
# 2  30.0      NaN    None
# 3  35.0  80000.0    Pune
# 4  30.0  90000.0   Delhi

# %%
df2 = df.copy()
df2["City"].fillna(df2["City"].mode()[0], inplace=True)

df2
# Out:
# /tmp/ipykernel_2458/3096974920.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df2["City"].fillna(df2["City"].mode()[0], inplace=True)
#     Age   Salary    City
# 0  25.0  50000.0  Mumbai
# 1   NaN  60000.0   Delhi
# 2  30.0      NaN   Delhi
# 3  35.0  80000.0    Pune
# 4   NaN  90000.0   Delhi

# %%
df_ffill = df.fillna(method="ffill")
df_ffill
# Out:
# /tmp/ipykernel_2458/1246910402.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_ffill = df.fillna(method="ffill")
#     Age   Salary    City
# 0  25.0  50000.0  Mumbai
# 1  25.0  60000.0   Delhi
# 2  30.0  60000.0   Delhi
# 3  35.0  80000.0    Pune
# 4  35.0  90000.0   Delhi

# %%
df_bfill = df.fillna(method="bfill")
df_bfill
# Out:
# /tmp/ipykernel_2458/1714158225.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_bfill = df.fillna(method="bfill")
#     Age   Salary    City
# 0  25.0  50000.0  Mumbai
# 1  30.0  60000.0   Delhi
# 2  30.0  80000.0    Pune
# 3  35.0  80000.0    Pune
# 4   NaN  90000.0   Delhi

# %%
df["Age_missing"] = df["Age"].isnull().astype(int)

df
# Out:
#     Age   Salary    City  Age_missing
# 0  25.0  50000.0  Mumbai            0
# 1   NaN  60000.0   Delhi            1
# 2  30.0      NaN    None            0
# 3  35.0  80000.0    Pune            0
# 4   NaN  90000.0   Delhi            1

# %% [markdown]
# Feature Selection:
# selecting important features for the model and removing unnecessary ones

# %%
import pandas as pd

data = {
    "Age": [25, 30, 35, 40, 45],
    "Salary": [30000, 40000, 50000, 60000, 70000],
    "Experience": [1, 3, 5, 7, 9],
    "Purchased": [0, 0, 1, 1, 1]  # Target variable
}

df = pd.DataFrame(data)
df
# Out:
#    Age  Salary  Experience  Purchased
# 0   25   30000           1          0
# 1   30   40000           3          0
# 2   35   50000           5          1
# 3   40   60000           7          1
# 4   45   70000           9          1

# %%
# Correlation matrix
df.corr()
# Out:
#                  Age    Salary  Experience  Purchased
# Age         1.000000  1.000000    1.000000   0.866025
# Salary      1.000000  1.000000    1.000000   0.866025
# Experience  1.000000  1.000000    1.000000   0.866025
# Purchased   0.866025  0.866025    0.866025   1.000000

# %%
# Correlation with target
corr_with_target = df.corr()["Purchased"]

corr_with_target
# Out:
# Age           0.866025
# Salary        0.866025
# Experience    0.866025
# Purchased     1.000000
# Name: Purchased, dtype: float64

# %%
# Example: Drop a feature (if low importance)
df_selected = df.drop(columns=["Age"])  # just for demo

df_selected
# Out:
#    Salary  Experience  Purchased
# 0   30000           1          0
# 1   40000           3          0
# 2   50000           5          1
# 3   60000           7          1
# 4   70000           9          1

# %% [markdown]
# Handling ouliers
# 1.IQR(interquartile range)
# 2.z-score
# 3.visualizatin
# Treatment methods:
# remove outliers
# cap values (limit max/min)
# transform data(log)

# %%
import pandas as pd

data = {
    "Salary": [30000, 35000, 40000, 45000, 50000, 1000000]  # Outlier present
}

df = pd.DataFrame(data)
df
# Out:
#     Salary
# 0    30000
# 1    35000
# 2    40000
# 3    45000
# 4    50000
# 5  1000000

# %%
Q1 = df["Salary"].quantile(0.25)
Q3 = df["Salary"].quantile(0.75)

IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

lower_bound, upper_bound

# Detect outliers
outliers = df[(df["Salary"] < lower_bound) | (df["Salary"] > upper_bound)]

print(outliers)
# Out:
#     Salary
# 5  1000000

# %%
# identify outliers
outliers = df[(df["Salary"] < lower_bound) | (df["Salary"] > upper_bound)]
outliers
# Out:
#     Salary
# 5  1000000

# %%
# no outliers
df_no_outliers = df[(df["Salary"] >= lower_bound) & (df["Salary"] <= upper_bound)]
df_no_outliers
# Out:
#    Salary
# 0   30000
# 1   35000
# 2   40000
# 3   45000
# 4   50000

# %%
# cap outliers
df_capped = df.copy()

df_capped["Salary"] = df_capped["Salary"].clip(lower_bound, upper_bound)
df_capped
# Out:
#    Salary
# 0   30000
# 1   35000
# 2   40000
# 3   45000
# 4   50000
# 5   67500

# %%
from scipy import stats

z_scores = stats.zscore(df["Salary"])
z_scores
# Out:
# array([-0.47508713, -0.46111398, -0.44714082, -0.43316767, -0.41919452,
#         2.23570412])

# %%
# z_score
df_z = df[(abs(z_scores) > 2)]
df_z
# Out:
#     Salary
# 5  1000000
